# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu, sigma = 0, 1

s = np.random.normal(mu, sigma, 10000)

# %%
s
# Out:
# array([ 1.04364213,  2.04913876,  0.2314252 , ...,  1.07450992,
#        -1.46999386, -0.94335889])

# %%
plt.plot(s)

# %%
for i in range(1,3):
    mu,sigma = 0 ,1
    s = np.random.normal(mu,sigma, 1050624)
    np.savetxt("imgarray4096_{}.dat".format(i), s)

# %%
for i in range(1,3):
    mu,sigma = 0 ,1
    s = np.random.normal(mu,sigma, 1050624)
    np.savetxt("realarray4096_{}.dat".format(i), s)
